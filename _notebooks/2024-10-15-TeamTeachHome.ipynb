# %% [raw]
# ---
# layout: post
# title:  Team Teach Home
# description:  Overview of Sprint 2
# courses: { csp: {week 7} }
# comments: true
# sticky_rank: 1
# ---

# %% [markdown]
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta http-equiv="X-UA-Compatible="IE=edge">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Programming Topics</title>
#     <style>
#         body {
#             display: flex;
#             justify-content: center;
#             align-items: center;
#             height: 100vh;
#             background-color: #2c2c2c;
#             color: #fff;
#             font-family: Arial, sans-serif;
#             margin: 0;
#         }
#
#         .container {
#             text-align: center;
#             max-width: 800px;
#         }
#
#         .title {
#             font-size: 2.5rem;
#             margin-bottom: 30px;
#             color: #4caf50;
#         }
#
#         .topics {
#             display: grid;
#             grid-template-columns: repeat(auto-fit, minmax(250px, 1fr));
#             gap: 20px;
#         }
#
#         .topic {
#             background-color: #333;
#             padding: 20px;
#             border: 1px solid #444;
#             border-radius: 8px;
#             position: relative;
#             cursor: pointer;
#             transition: background-color 0.3s, transform 0.2s;
#             text-align: center;
#         }
#
#         .topic:hover {
#             background-color: #555;
#             transform: translateY(-5px);
#         }
#
#         .description {
#             display: none;
#             position: absolute;
#             bottom: 110%;
#             left: 50%;
#             transform: translateX(-50%);
#             background-color: #222;
#             padding: 10px;
#             border: 1px solid #444;
#             border-radius: 5px;
#             white-space: nowrap;
#             color: #fff;
#             z-index: 1;
#             font-size: 0.9rem;
#             max-width: 200px;
#         }
#
#         .topic:hover .description {
#             display: block;
#         }
#
#         .link-button {
#             margin-top: 30px;
#             background-color: #1e90ff;
#             color: white;
#             padding: 12px 25px;
#             text-decoration: none;
#             border-radius: 5px;
#             transition: background-color 0.3s;
#         }
#
#         .link-button:hover {
#             background-color: #0073e6;
#         }
#     </style>
# </head>
# <body>
#     <div class="container">
#         <div class="title">Programming Topics</div>
#         <div class="topics">
#             <div class="topic" onclick="window.location.href='https://nolanyu1111.github.io/Nolans_student_2025_/2024/10/07/3.1homeworkhackpopcornhack_IPYNB_2_.html'">
#                 Unit 1 — Data Types
#                 <div class="description">Detailed overview of primitive and reference data types used in Java.</div>
#             </div>
#             <div class="topic" onclick="window.location.href='https://nolanyu1111.github.io/Nolans_student_2025_/2024/10/08/3.2.1homeworkandpopcornhacks_IPYNB_2_.html'">
#                 Unit 2 — Using Objects
#                 <div class="description">Techniques for creating and utilizing objects in Java programming.</div>
#             </div>
#             <div class="topic" onclick="window.location.href='https://nolanyu1111.github.io/Nolans_student_2025_/2024/10/09/3-3-and-5homework_IPYNB_2_.html'">
#                 Unit 3 — Boolean Expressions
#                 <div class="description">Logical operators and conditions that help in making decisions in code.</div>
#             </div>
#             <div class="topic" onclick="window.location.href='https://nolanyu1111.github.io/Nolans_student_2025_/2024/10/08/3.4homeworkhack_IPYNB_2_.html'">
#                 Unit 4 — Iteration
#                 <div class="description">Working with loops such as for, while, and do-while for repetitive tasks.</div>
#             </div>
#             <div class="topic" onclick="window.location.href='https://nolanyu1111.github.io/Nolans_student_2025_/2024/10/09/3-3-and-5homework_IPYNB_2_.html'">
#                 Unit 5 — Writing Classes
#                 <div class="description">How to create well-structured classes and methods in Java.</div>
#             </div>
#             <div class="topic" onclick="window.location.href='https://kush1434.github.io/portfolio_2025/csp/big-idea/p2/3-6'">
#                 Unit 6 — Arrays
#                 <div class="description">Using arrays to store collections of data in an organized manner.</div>
#             </div>
#             <div class="topic" onclick="window.location.href='https://kush1434.github.io/portfolio_2025/csp/big-idea/p2/3-7'">
#                 Unit 7 — ArrayLists
#                 <div class="description">Dynamic data handling with ArrayLists for flexible storage solutions.</div>
#             </div>
#             <div class="topic" onclick="window.location.href='https://nolanyu1111.github.io/Nolans_student_2025_/2024/10/04/3.8homeworkpopcornhack_IPYNB_2_.html'">
#                 Unit 8 — 2D Arrays
#                 <div class="description">Working with two-dimensional arrays to handle matrix-like data.</div>
#             </div>
#             <div class="topic" onclick="window.location.href='https://nolanyu1111.github.io/Nolans_student_2025_/2024/10/04/3.10homeworkandpopcornhacks(1)_IPYNB_2_.html'">
#                 Unit 9 — Java Inheritance
#                 <div class="description">Exploring inheritance to build hierarchical class structures in Java.</div>
#             </div>
#         </div>
#         <a class="link-button" href="https://github.com/NolanYu1111/Nolans_student_2025_/issues/3">Go to My Issue</a>
#     </div>
# </body>
# </html>

# %% [markdown]
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta http-equiv="X-UA-Compatible" content="IE=edge">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Team Teach Home</title>
#     <style>
#         body {
#             display: flex;
#             justify-content: center;
#             align-items: center;
#             height: 100vh;
#             background-color: #2c2c2c;
#             color: #fff;
#             font-family: Arial, sans-serif;
#             margin: 0;
#         }
#
#         .container {
#             text-align: center;
#         }
#
#         .title {
#             font-size: 2.5rem;
#             margin-bottom: 30px;
#             color: #4caf50;
#         }
#
#         /* Horizontal navigation bar styles */
#         .topics {
#             display: flex;
#             justify-content: center;
#             flex-wrap: wrap;
#             gap: 20px;
#             background-color: #333;
#             padding: 10px;
#             border-radius: 8px;
#         }
#
#         /* Topic item styles */
#         .topic {
#             position: relative;
#             padding: 10px 20px;
#             cursor: pointer;
#             background-color: #333;
#             border: 1px solid #444;
#             border-radius: 8px;
#             transition: background-color 0.3s, transform 0.2s;
#             text-align: center;
#             color: #1e90ff;
#         }
#
#         .topic:hover {
#             background-color: #555;
#             transform: translateY(-5px);
#         }
#
#         /* Submenu styles */
#         .submenu {
#             display: none;
#             position: absolute;
#             top: 100%; /* Align below the main topic */
#             left: 50%;
#             transform: translateX(-50%);
#             background-color: #222;
#             padding: 10px;
#             border: 1px solid #444;
#             border-radius: 5px;
#             text-align: left;
#             white-space: nowrap;
#             z-index: 1;
#         }
#
#         .submenu a {
#             display: block;
#             color: #fff;
#             text-decoration: none;
#             padding: 5px 0;
#         }
#
#         .submenu a:hover {
#             background-color: #444;
#         }
#
#         /* Show the submenu on hover */
#         .topic:hover .submenu {
#             display: block;
#         }
#
#         .link-button {
#             margin-top: 30px;
#             background-color: #1e90ff;
#             color: white;
#             padding: 12px 25px;
#             text-decoration: none;
#             border-radius: 5px;
#             transition: background-color 0.3s;
#         }
#
#         .link-button:hover {
#             background-color: #0073e6;
#         }
#
#         /* Dropdown button and menu styles */
#         .dropdown-container {
#             position: relative;
#             display: inline-block;
#             margin-top: 20px;
#         }
#
#         .dropdown-button {
#             background-color: #1e90ff;
#             color: white;
#             padding: 12px 25px;
#             text-decoration: none;
#             border-radius: 5px;
#             cursor: pointer;
#             transition: background-color 0.3s;
#             display: inline-block;
#         }
#
#         .dropdown-button:hover {
#             background-color: #0073e6;
#         }
#
#         .dropdown-menu {
#             display: none;
#             position: absolute;
#             background-color: #222;
#             min-width: 160px;
#             border: 1px solid #444;
#             border-radius: 5px;
#             z-index: 1;
#             text-align: left;
#             padding: 10px;
#         }
#
#         .dropdown-menu a {
#             color: #fff;
#             text-decoration: none;
#             padding: 8px 10px;
#             display: block;
#         }
#
#         .dropdown-menu a:hover {
#             background-color: #444;
#         }
#
#         .dropdown-container:hover .dropdown-menu {
#             display: block;
#         }
#     </style>
# </head>
# <body>
#     <div class="container">
#         <div class="title">Team Teach Home</div>
#         <div class="topics">
#             <div class="topic">
#                 Variables
#                 <div class="submenu">
#                     <a href="https://nolanyu1111.github.io/Nolans_student_2025_/2024/10/07/3.1homeworkhackpopcornhack_IPYNB_2_.html">Primitive Data Types</a>
#                 </div>
#             </div>
#             <div class="topic">
#                 Data Abstraction
#                 <div class="submenu">
#                     <a href="https://nolanyu1111.github.io/Nolans_student_2025_/2024/10/08/3.2.1homeworkandpopcornhacks_IPYNB_2_.html">Creating Objects</a>
#                 </div>
#             </div>
#             <div class="topic">
#                 Mathematical Expressions
#                 <div class="submenu">
#                     <a href="https://nolanyu1111.github.io/Nolans_student_2025_/2024/10/09/3-3-and-5homework_IPYNB_2_.html">Logical Operators</a>
#                 </div>
#             </div>
#             <div class="topic">
#                 Strings
#                 <div class="submenu">
#                     <a href="https://nolanyu1111.github.io/Nolans_student_2025_/2024/10/08/3.4homeworkhack_IPYNB_2_.html">String Methods</a>
#                 </div>
#             </div>
#             <div class="topic">
#                 Boolean Expressions
#                 <div class="submenu">
#                     <a href="#">Conditional Statements</a>
#                 </div>
#             </div>
#             <div class="topic">
#                 Conditionals
#                 <div class="submenu">
#                     <a href="#">If-Else Statements</a>
#                 </div>
#             </div>
#             <div class="topic">
#                 Nested Conditionals
#                 <div class="submenu">
#                     <a href="#">Nested Ifs</a>
#                 </div>
#             </div>
#             <div class="topic">
#                 Iteration
#                 <div class="submenu">
#                     <a href="#">For Loops</a>
#                     <a href="#">While Loops</a>
#                 </div>
#             </div>
#             <div class="topic">
#                 List Operations
#                 <div class="submenu">
#                     <a href="#">Array Methods</a>
#                     <a href="#">List Handling</a>
#                 </div>
#             </div>
#         </div>
#         <a class="link-button" href="https://github.com/NolanYu1111/Nolans_student_2025_/issues/3">Go to My Issue</a>
#
#         <div class="dropdown-container">
#             <div class="dropdown-button">Sprint 2 Final Hacks</div>
#             <div class="dropdown-menu">
#                 <a href="#">Hack 1</a>
#                 <a href="#">Hack 2</a>
#                 <a href="#">Hack 3</a>
#                 <a href="#">Hack 4</a>
#             </div>
#         </div>
#     </div>
# </body>
# </html>
