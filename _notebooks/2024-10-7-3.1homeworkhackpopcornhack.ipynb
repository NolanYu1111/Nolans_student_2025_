# %%
---
layout: post
title: 3.1 Homework and Popcorn Hacks  
description:  Homework and Popcorn Hacks 
courses: { csp: {week 2} } 
comments: true
sticky_rank: 1
---

# %% [markdown]
# # 3.1 Popcorn Hacks

# %% [markdown]
# # Popcorn Hack #1

# %%
# Creating the dictionary with fruit names as keys
fruits = {
    'apple': 1,
    'banana': 2,
    'cherry': 3
}

# Accessing and printing the value corresponding to the key 'banana'
print(fruits['banana'])
# Out:
# 2

# %% [markdown]
# # Popcorn Hack #2

# %%
import random

def generate_question():
    # Generate two random numbers and a random operator
    num1 = random.randint(1, 10)
    num2 = random.randint(1, 10)
    operator = random.choice(['+', '-', '*'])

    # Form the question string and calculate the correct answer
    if operator == '+':
        correct_answer = num1 + num2
    elif operator == '-':
        correct_answer = num1 - num2
    else:
        correct_answer = num1 * num2

    question = f"{num1} {operator} {num2}"
    return question, correct_answer

def math_quiz():
    score = 0
    num_questions = 5  # Number of questions to ask

    print("Welcome to the Math Quiz! Answer the following questions:")

    for i in range(num_questions):
        question, correct_answer = generate_question()
        print(f"Question {i+1}: {question} = ?")
        try:
            user_answer = int(input("Your answer: "))
        except ValueError:
            print("Please enter a valid number!")
            continue

        if user_answer == correct_answer:
            print("Correct!")
            score += 1
        else:
            print(f"Wrong! The correct answer was {correct_answer}.")

    print(f"\nYou answered {score} out of {num_questions} questions correctly.")

# Start the quiz
math_quiz()
# Out:
# Welcome to the Math Quiz! Answer the following questions:
# Question 1: 7 - 5 = ?
# Wrong! The correct answer was 2.
# Question 2: 1 - 9 = ?
# Correct!
# Question 3: 4 - 8 = ?
# Please enter a valid number!
# Question 4: 7 - 9 = ?
# Wrong! The correct answer was -2.
# Question 5: 3 + 2 = ?
# Correct!
#
# You answered 2 out of 5 questions correctly.

# %% [markdown]
# # Popcorn Hack 3

# %%
def celsius_to_fahrenheit(celsius):
    return (celsius * 9/5) + 32

def fahrenheit_to_celsius(fahrenheit):
    return (fahrenheit - 32) * 5/9

def temperature_converter():
    print("Welcome to the Temperature Converter!")

    # Ask the user for the temperature to convert
    try:
        temperature = float(input("Enter the temperature: "))
    except ValueError:
        print("Please enter a valid number for the temperature.")
        return

    # Ask the user for the conversion direction
    print("Choose the conversion direction:")
    print("1. Celsius to Fahrenheit")
    print("2. Fahrenheit to Celsius")
    choice = input("Enter 1 or 2: ")

    # Perform the conversion based on the user's choice
    if choice == '1':
        converted_temp = celsius_to_fahrenheit(temperature)
        print(f"{temperature}°C is equal to {converted_temp:.2f}°F")
    elif choice == '2':
        converted_temp = fahrenheit_to_celsius(temperature)
        print(f"{temperature}°F is equal to {converted_temp:.2f}°C")
    else:
        print("Invalid choice. Please enter 1 or 2.")

# Start the temperature conversion program
temperature_converter()

# %% [markdown]
# # 3.1 Homework Hacks

# %% [markdown]
# # Homework Hack #1

# %%
# Shopping List Calculator

# Function to add an item to the shopping list
def add_item(shopping_list):
    item = input("Enter the item name: ")
    price = float(input(f"Enter the price of {item}: "))
    shopping_list[item] = price
    print(f"{item} has been added with a price of ${price:.2f}.")

# Function to calculate the total cost of the shopping list
def calculate_total(shopping_list):
    total = sum(shopping_list.values())
    return total

# Main function to run the shopping list calculator
def main():
    shopping_list = {}
    while True:
        print("\nShopping List Calculator")
        print("1. Add item")
        print("2. Calculate total cost")
        print("3. Show shopping list")
        print("4. Exit")
        
        choice = input("Choose an option (1-4): ")
        
        if choice == '1':
            add_item(shopping_list)
        elif choice == '2':
            total_cost = calculate_total(shopping_list)
            print(f"\nTotal cost: ${total_cost:.2f}")
        elif choice == '3':
            print("\nShopping List:")
            for item, price in shopping_list.items():
                print(f"{item}: ${price:.2f}")
        elif choice == '4':
            print("Exiting the program. Goodbye!")
            break
        else:
            print("Invalid choice. Please select a valid option.")

# Run the shopping list calculator
if __name__ == "__main__":
    main()
# Out:
# Shopping List Calculator
# 1. Add item
# 2. Calculate total cost
# 3. Show shopping list
# 4. Exit
# 1 has been added with a price of $2.00.
#
# Shopping List Calculator
# 1. Add item
# 2. Calculate total cost
# 3. Show shopping list
# 4. Exit
#
# Shopping List:
# 1: $2.00
#
# Shopping List Calculator
# 1. Add item
# 2. Calculate total cost
# 3. Show shopping list
# 4. Exit
#
# Total cost: $2.00
#
# Shopping List Calculator
# 1. Add item
# 2. Calculate total cost
# 3. Show shopping list
# 4. Exit
# Invalid choice. Please select a valid option.
#
# Shopping List Calculator
# 1. Add item
# 2. Calculate total cost
# 3. Show shopping list
# 4. Exit
# Invalid choice. Please select a valid option.
#
# Shopping List Calculator
# 1. Add item
# 2. Calculate total cost
# 3. Show shopping list
# 4. Exit
# Invalid choice. Please select a valid option.
#
# Shopping List Calculator
# 1. Add item
# 2. Calculate total cost
# 3. Show shopping list
# 4. Exit
# Invalid choice. Please select a valid option.
#
# Shopping List Calculator
# 1. Add item
# 2. Calculate total cost
# 3. Show shopping list
# 4. Exit
# Invalid choice. Please select a valid option.
#
# Shopping List Calculator
# 1. Add item
# 2. Calculate total cost
# 3. Show shopping list
# 4. Exit
# Invalid choice. Please select a valid option.
#
# Shopping List Calculator
# 1. Add item
# 2. Calculate total cost
# 3. Show shopping list
# 4. Exit
# Invalid choice. Please select a valid option.
#
# Shopping List Calculator
# 1. Add item
# 2. Calculate total cost
# 3. Show shopping list
# 4. Exit
# Invalid choice. Please select a valid option.
#
# Shopping List Calculator
# 1. Add item
# 2. Calculate total cost
# 3. Show shopping list
# 4. Exit
# Invalid choice. Please select a valid option.
#
# Shopping List Calculator
# 1. Add item
# 2. Calculate total cost
# 3. Show shopping list
# 4. Exit
# Invalid choice. Please select a valid option.
#
# Shopping List Calculator
# 1. Add item
# 2. Calculate total cost
# 3. Show shopping list
# 4. Exit
# Invalid choice. Please select a valid option.
#
# Shopping List Calculator
# 1. Add item
# 2. Calculate total cost
# 3. Show shopping list
# 4. Exit
# Invalid choice. Please select a valid option.
#
# Shopping List Calculator
# 1. Add item
# 2. Calculate total cost
# 3. Show shopping list
# 4. Exit
#
# Total cost: $2.00
#
# Shopping List Calculator
# 1. Add item
# 2. Calculate total cost
# 3. Show shopping list
# 4. Exit
#
# Shopping List:
# 1: $2.00
#
# Shopping List Calculator
# 1. Add item
# 2. Calculate total cost
# 3. Show shopping list
# 4. Exit
# Invalid choice. Please select a valid option.
#
# Shopping List Calculator
# 1. Add item
# 2. Calculate total cost
# 3. Show shopping list
# 4. Exit
# Invalid choice. Please select a valid option.
#
# Shopping List Calculator
# 1. Add item
# 2. Calculate total cost
# 3. Show shopping list
# 4. Exit
# Invalid choice. Please select a valid option.
#
# Shopping List Calculator
# 1. Add item
# 2. Calculate total cost
# 3. Show shopping list
# 4. Exit
# Invalid choice. Please select a valid option.
#
# Shopping List Calculator
# 1. Add item
# 2. Calculate total cost
# 3. Show shopping list
# 4. Exit
# Invalid choice. Please select a valid option.
#
# Shopping List Calculator
# 1. Add item
# 2. Calculate total cost
# 3. Show shopping list
# 4. Exit
# Invalid choice. Please select a valid option.
#
# Shopping List Calculator
# 1. Add item
# 2. Calculate total cost
# 3. Show shopping list
# 4. Exit
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 44
#      42 # Run the shopping list calculator
#      43 if __name__ == "__main__":
# ---> 44     main()
#
# Cell In[3], line 25, in main()
#      22 print("3. Show shopping list")
#      23 print("4. Exit")
# ---> 25 choice = input("Choose an option (1-4): ")
#      27 if choice == '1':
#      28     add_item(shopping_list)
#
# File ~/nighthawk/Nolan_student_2025_/venv/lib/python3.12/site-packages/ipykernel/kernelbase.py:1282, in Kernel.raw_input(self, prompt)
#    1280     msg = "raw_input was called, but this frontend does not support input requests."
#    1281     raise StdinNotImplementedError(msg)
# -> 1282 return self._input_request(
#    1283     str(prompt),
#    1284     self._parent_ident["shell"],
#    1285     self.get_parent("shell"),
#    1286     password=False,
#    1287 )
#
# File ~/nighthawk/Nolan_student_2025_/venv/lib/python3.12/site-packages/ipykernel/kernelbase.py:1325, in Kernel._input_request(self, prompt, ident, parent, password)
#    1322 except KeyboardInterrupt:
#    1323     # re-raise KeyboardInterrupt, to truncate traceback
#    1324     msg = "Interrupted by user"
# -> 1325     raise KeyboardInterrupt(msg) from None
#    1326 except Exception:
#    1327     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
